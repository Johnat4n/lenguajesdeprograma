# %% [markdown]
# **TALLER DE REFUERZO**

# %% [markdown]
# ***1. FOR***

# %% [markdown]
# Escribir un programa que pregunte al usuario su edad y
# muestre por pantalla todos los años que ha cumplido
# (desde 1 hasta su edad).

# %%
edad= int(input(" ¿Cuantos años tiene? : "))
print("Años que ha cumplido segun su edad son: ")
for i in range(1,edad+1):
  print(i)

# %% [markdown]
# Se necesita un sistema que pida un sueldo de un
# trabajador, si el sueldo es mayor a 655000, no tedrá
# ninguna bonificación, pero si es menor tiene bonificación
# del 4%. Al final se desea saber el total del sueldo con
# o sin bonificación.

# %% [markdown]
# **2. WHILE**

# %%
resp= "si"
while resp == "si" or resp == "Si":
  sueldo_= int( input(" Digite su sueldo $ "))

  if sueldo_ < 655000:
    bonificacion = sueldo_* 0.4
    
print(f" La bonificación es de = {bonificacion:,.0f} y el salario total con o sin bonificación es = {sueldo_ + bonificacion:,.0f}")

 else:
    bonificacion= " No obtendra bonificación "

print(f" La bonificación es de = {bonificacion:,.0f} y el salario total con o sin bonificación es = {sueldo_ + bonificacion:,.0f}")

  resp = input( " ¿Desea calcular otro sueldo? ")
