# %% [markdown]
# **TALLER N°1**

# %%
nombre="Johnatan Javier "
apellido="Molina Castellanos"
print(nombre+""+apellido)
n_indentifi=1022422316
print(n_indentifi)
dirección="KR 103#73-51"
print(dirección)
telefono=3134932110
print(telefono)
edad=26
print(edad)
estado_civil="Soltero"
print(estado_civil)
n_hijos=0
print(n_hijos)
estatura="1.75 cm"
print(estatura)
fecha_contrata="01 de Agosto de 2022"
print(fecha_contrata)
sueldo="1.500.000"
print(sueldo)
diaslab=input("digite dias laborados ")
print(diaslab)
# Out:
# Johnatan Javier Molina Castellanos
# 1022422316
# KR 103#73-51
# 3134932110
# 26
# Soltero
# 0
# 1.75 cm
# 01 de Agosto de 2022
# 1.500.000

# %% [markdown]
# **TALLER N°2**

# %% [markdown]
# Si el empleado es mayor de 55 años disfrutará de un bono de prepensión correspondiente al 5% de su sueldo básico

# %%
edad_emple=int(input( "¿Cuantos años tiene? "))
if edad_emple> 55:
  bono="Obtiene bono del 5% "
else:
  bono="no obtiene bono"
print(f"edad empleado es = {edad_emple} bono = {bono}")

# %% [markdown]
# Si el empleado es casado y tiene hijos se le otorga un paseo cada diciembre

# %%
estado_ci=input(" Digite su estado civil: ")
can_hijos=int(input(" Digite si tiene hijo: "))
if estado_ci in "casado" or estado_ci in "casada" and can_hijos > 0: 
  permiso=" Otorgado"
else:
  permiso= "No otorgado"
print(f" Estado civil del empleado es = {estado_ci} , Cantidad de hijos= {can_hijos} permiso para viajar cada diciembre = {permiso} ")

# %% [markdown]
# Si el sueldo básico esta entre 1.000.000 y 1.500.000 tendra un comisión del 2% sobre el valor del sueldo; si el sueldo básico está entre 1.500.001 y 2.000.000 tendra una comisión del 5% sobre el valor del sueldo; para todos los demas casos no habrá comisión.

# %%
sueldo_basi=float(input(" Digite su salario básico : $ "))
if sueldo_basi >= 1000000 and sueldo_basi <= 1500000:
  comisión1= sueldo_basi * 0.2
  print(f" la comisión es = {comisión1:,.0f} y el salario total es = {sueldo_basi + comisión1:,.0f}")

elif sueldo_basic >= 1500001 and sueldo_basi <= 2000000:
  comisión2= sueldo_basi * 0.5
  print(f" la comisión es = {comisión2:,.0f} y el salario total es = {sueldo_basi + comisión2:,.0f}")

else:
  print("No habra comisión")

# %% [markdown]
# Si el empleado trabajo mas de 20 días al mes y su sueldo es menor a 1000000 tendrá derecho a un bono de alimentación.

# %%
dias_traba=int(input(" Digite dias trabajados: "))
sueldo_basi=float(input(" Digite sueldo: $ "))
if dias_traba >20 and sueldo_basi <= 1000000:
  bono_ali=" Tendra bono de alimentación" 

else:
  bono_ali=" No tendra bono de alimentación"

print(f" dias trabajados al mes es = {dias_traba} su sueldo es = {sueldo_basi:,.0f} y {bono_ali}")
